# %%
import requests
r = requests.post("http://localhost:11434/api/generate",
    json={"model": "mistral-nemo", "prompt": "say hello", "stream": False})
print(r.json()["response"])
# Out:
# Hello! How can I assist you today?
